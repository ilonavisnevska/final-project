# %%
#Petīta informācija par iesniegtām skaidrās naudas deklarācijām iebraucot Latvijas terirorijā.
# avots:https://data.gov.lv/dati/lv/dataset/uz-robezas-deklaretie-skaidras-naudas-lidzekli/resource/a11f789d-cee5-4b9b-9fda-e365b317c691
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use ('ggplot')

# %%
data = pd.read_csv('/Users/Alienware/Github/FinalProject_Visnevska/snd_odata.csv')

# %%
data.head()
# Out:
#    Gads   Mēnesis Iebraucot LR vai Izbraucot LR         Nosūtītāja valsts  \
# 0  2018  janvāris                  Iebraucot LR  Apvienotie Arābu Emirāti
# 1  2018  janvāris                  Iebraucot LR              Azerbaidžāna
# 2  2018  janvāris                  Iebraucot LR              Baltkrievija
# 3  2018  janvāris                  Iebraucot LR                   Izraēla
# 4  2018  janvāris                  Iebraucot LR      Krievijas Federācija
#
#   Galamērķa valsts     Transporta veids Muitas punkta kods  \
# 0          Latvija     Gaisa transports             '0240'
# 1          Latvija     Gaisa transports             '0240'
# 2          Latvija  Autoceļu transports             '0814'
# 3          Latvija     Gaisa transports             '0240'
# 4          Beļģija     Gaisa transports             '0240'
#
#   Muitas punkta nosaukums  Kopsumma euro  Deklarāciju skaits
# 0            LIDOSTAS MKP       35000.00                   1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840 entries, 0 to 839
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Gads                           840 non-null    int64
#  1   Mēnesis                        840 non-null    object
#  2   Iebraucot LR vai Izbraucot LR  840 non-null    object
#  3   Nosūtītāja valsts              840 non-null    object
#  4   Galamērķa valsts               840 non-null    object
#  5   Transporta veids               840 non-null    object
#  6   Muitas punkta kods             840 non-null    object
#  7   Muitas punkta nosaukums        840 non-null    object
#  8   Kopsumma euro                  840 non-null    float64
#  9   Deklarāciju skaits             840 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 65.8+ KB

# %%
pd.options.display.float_format = '{:.2f}'.format
data.describe()
# Out:
#          Gads  Kopsumma euro  Deklarāciju skaits
# count  840.00         840.00              840.00
# mean  2018.74      518679.16                2.46
# std      0.67     2270243.07                4.02
# min   2018.00        3000.00                1.00
# 25%   2018.00       17934.99                1.00
# 50%   2019.00       38669.67                1.00
# 75%   2019.00      129850.35                2.00
# max   2020.00    31604886.40               32.00

# %%
data.describe(include=['O'])
# Out:
#           Mēnesis Iebraucot LR vai Izbraucot LR     Nosūtītāja valsts  \
# count         840                           840                   840
# unique         12                             4                    46
# top     februāris                  Iebraucot ES  Krievijas Federācija
# freq           93                           365                   240
#
#        Galamērķa valsts  Transporta veids Muitas punkta kods  \
# count               840               840                840
# unique               46                 7                 10
# top             Latvija  Gaisa transports             '0240'
# freq                381               604                566
#
#        Muitas punkta nosaukums
# count                      840
# unique                      10
# top               LIDOSTAS MKP
# freq                       566

# %%
data = data.drop(['Muitas punkta kods'], axis = 1)
data
# Out:
#      Gads   Mēnesis Iebraucot LR vai Izbraucot LR         Nosūtītāja valsts  \
# 0    2018  janvāris                  Iebraucot LR  Apvienotie Arābu Emirāti
# 1    2018  janvāris                  Iebraucot LR              Azerbaidžāna
# 2    2018  janvāris                  Iebraucot LR              Baltkrievija
# 3    2018  janvāris                  Iebraucot LR                   Izraēla
# 4    2018  janvāris                  Iebraucot LR      Krievijas Federācija
# ..    ...       ...                           ...                       ...
# 835  2020     marts               Izbraucot no ES                   Latvija
# 836  2020     marts               Izbraucot no ES                   Latvija
# 837  2020   aprīlis                  Iebraucot ES      Krievijas Federācija
# 838  2020   aprīlis                  Iebraucot ES                   Lietuva
# 839  2020   aprīlis               Izbraucot no ES                  Igaunija
#
#          Galamērķa valsts     Transporta veids  \
# ...

# %%
data["Transporta veids"].unique()
# Out:
# array(['Gaisa transports', 'Autoceļu transports', 'Dzelzceļa transports',
#        'Pārvietošana bez transp. līdz.', 'Autotransports',
#        'Transporta veids nav zināms (proti, pārvieto pats)',
#        'Jūras transports'], dtype=object)

# %%
data[["Transporta veids", 'Deklarāciju skaits']].groupby(["Transporta veids"]).sum()
# Out:
#                                                     Deklarāciju skaits
# Transporta veids
# Autoceļu transports                                                131
# Autotransports                                                     156
# Dzelzceļa transports                                                22
# Gaisa transports                                                  1752
# Jūras transports                                                     1
# Pārvietošana bez transp. līdz.                                       1
# Transporta veids nav zināms (proti, pārvieto pats)                   7

# %%
data["Transporta veids"].replace(['Transporta veids nav zināms (proti, pārvieto pats)', 'Pārvietošana bez transp. līdz.'],['Pārvieto pats','Pārvieto pats'], inplace = True)

# %%
set(data["Transporta veids"])
# Out:
# {'Autoceļu transports',
#  'Autotransports',
#  'Dzelzceļa transports',
#  'Gaisa transports',
#  'Jūras transports',
#  'Pārvieto pats'}

# %%
data["Iebraucot LR vai Izbraucot LR"].unique()
# Out:
# array(['Iebraucot LR', 'Izbraucot no LR', 'Iebraucot ES',
#        'Izbraucot no ES'], dtype=object)

# %%
sb.countplot("Iebraucot LR vai Izbraucot LR", data = data)
plt.show()

# %%
data.loc[data ["Iebraucot LR vai Izbraucot LR"] =='Iebraucot ES']
# Out:
#      Gads    Mēnesis Iebraucot LR vai Izbraucot LR         Nosūtītāja valsts  \
# 356  2019  februāris                  Iebraucot ES  Apvienotie Arābu Emirāti
# 357  2019  februāris                  Iebraucot ES              Azerbaidžāna
# 358  2019  februāris                  Iebraucot ES              Baltkrievija
# 359  2019  februāris                  Iebraucot ES                   Izraēla
# 360  2019  februāris                  Iebraucot ES      Krievijas Federācija
# ..    ...        ...                           ...                       ...
# 827  2020      marts                  Iebraucot ES                   Ukraina
# 828  2020      marts                  Iebraucot ES               Uzbekistāna
# 829  2020      marts                  Iebraucot ES               Uzbekistāna
# 837  2020    aprīlis                  Iebraucot ES      Krievijas Federācija
# 838  2020    aprīlis                  Iebraucot ES                   Lietuva
#
# ...

# %%
data.loc[data ["Iebraucot LR vai Izbraucot LR"] =='Izbraucot no ES']
# Out:
#      Gads    Mēnesis Iebraucot LR vai Izbraucot LR Nosūtītāja valsts  \
# 373  2019  februāris               Izbraucot no ES           Latvija
# 374  2019  februāris               Izbraucot no ES           Latvija
# 375  2019  februāris               Izbraucot no ES           Latvija
# 398  2019      marts               Izbraucot no ES           Latvija
# 399  2019      marts               Izbraucot no ES           Latvija
# ..    ...        ...                           ...               ...
# 833  2020      marts               Izbraucot no ES           Latvija
# 834  2020      marts               Izbraucot no ES           Latvija
# 835  2020      marts               Izbraucot no ES           Latvija
# 836  2020      marts               Izbraucot no ES           Latvija
# 839  2020    aprīlis               Izbraucot no ES          Igaunija
#
#          Galamērķa valsts  Transporta veids  \
# 373  Krievijas Federācija  Gaisa transports
# 374                Šveice  Gaisa transports
# ...

# %%
data.loc[data ["Iebraucot LR vai Izbraucot LR"] =='Iebraucot LR']
# Out:
#      Gads   Mēnesis Iebraucot LR vai Izbraucot LR         Nosūtītāja valsts  \
# 0    2018  janvāris                  Iebraucot LR  Apvienotie Arābu Emirāti
# 1    2018  janvāris                  Iebraucot LR              Azerbaidžāna
# 2    2018  janvāris                  Iebraucot LR              Baltkrievija
# 3    2018  janvāris                  Iebraucot LR                   Izraēla
# 4    2018  janvāris                  Iebraucot LR      Krievijas Federācija
# ..    ...       ...                           ...                       ...
# 343  2019  janvāris                  Iebraucot LR                   Ukraina
# 344  2019  janvāris                  Iebraucot LR                   Ukraina
# 345  2019  janvāris                  Iebraucot LR               Uzbekistāna
# 346  2019  janvāris                  Iebraucot LR               Uzbekistāna
# 347  2019  janvāris                  Iebraucot LR               Uzbekistāna
#
# ...

# %%
data.loc[data ["Iebraucot LR vai Izbraucot LR"] =='Izbraucot no LR']
# Out:
#      Gads   Mēnesis Iebraucot LR vai Izbraucot LR Nosūtītāja valsts  \
# 11   2018  janvāris               Izbraucot no LR           Latvija
# 12   2018  janvāris               Izbraucot no LR           Latvija
# 13   2018  janvāris               Izbraucot no LR           Latvija
# 14   2018  janvāris               Izbraucot no LR           Latvija
# 15   2018  janvāris               Izbraucot no LR           Latvija
# ..    ...       ...                           ...               ...
# 351  2019  janvāris               Izbraucot no LR           Latvija
# 352  2019  janvāris               Izbraucot no LR           Latvija
# 353  2019  janvāris               Izbraucot no LR           Latvija
# 354  2019  janvāris               Izbraucot no LR           Lietuva
# 355  2019  janvāris               Izbraucot no LR            Vācija
#
#                 Galamērķa valsts     Transporta veids Muitas punkta nosaukums  \
# ...

# %%
#var pieņemt, ka no 2019.gada februāra škersojot LR robežu "Izbraucot no LR" vietā izmanto "Izbraocot no ES",
# un "Izbraucot no LR" vietā izmanto "Izbraucot no ES"
data["Iebraucot LR vai Izbraucot LR"].replace(['Iebraucot LR','Iebraucot ES'],['Iebraucot','Iebraucot'], inplace = True)
data["Iebraucot LR vai Izbraucot LR"].replace(['Izbraucot no LR','Izbraucot no ES'],['Izbraucot','Izbraucot'], inplace = True)

# %%
set(data["Iebraucot LR vai Izbraucot LR"])
# Out:
# {'Iebraucot', 'Izbraucot'}

# %%
data_new =data.rename(columns = {'Iebraucot LR vai Izbraucot LR':'Iebraucot vai Izbraucot'})
data_new
# Out:
#      Gads   Mēnesis Iebraucot vai Izbraucot         Nosūtītāja valsts  \
# 0    2018  janvāris               Iebraucot  Apvienotie Arābu Emirāti
# 1    2018  janvāris               Iebraucot              Azerbaidžāna
# 2    2018  janvāris               Iebraucot              Baltkrievija
# 3    2018  janvāris               Iebraucot                   Izraēla
# 4    2018  janvāris               Iebraucot      Krievijas Federācija
# ..    ...       ...                     ...                       ...
# 835  2020     marts               Izbraucot                   Latvija
# 836  2020     marts               Izbraucot                   Latvija
# 837  2020   aprīlis               Iebraucot      Krievijas Federācija
# 838  2020   aprīlis               Iebraucot                   Lietuva
# 839  2020   aprīlis               Izbraucot                  Igaunija
#
#          Galamērķa valsts     Transporta veids  \
# 0                 Latvija     Gaisa transports
# ...

# %%
data_new[['Iebraucot vai Izbraucot','Kopsumma euro','Deklarāciju skaits']].groupby(['Iebraucot vai Izbraucot']).sum()
# Out:
#                          Kopsumma euro  Deklarāciju skaits
# Iebraucot vai Izbraucot
# Iebraucot                 183684608.30                1622
# Izbraucot                 252005886.73                 448

# %%
data_new[["Transporta veids", 'Kopsumma euro', 'Deklarāciju skaits']].groupby(["Transporta veids"]).sum()
# Out:
#                       Kopsumma euro  Deklarāciju skaits
# Transporta veids
# Autoceļu transports      4865925.09                 131
# Autotransports           4031986.19                 156
# Dzelzceļa transports      771094.91                  22
# Gaisa transports       425793147.51                1752
# Jūras transports           18470.00                   1
# Pārvieto pats             209871.33                   8

# %%
data_new[["Muitas punkta nosaukums", 'Kopsumma euro', 'Deklarāciju skaits']].groupby(["Muitas punkta nosaukums"]).sum()
# Out:
#                                      Kopsumma euro  Deklarāciju skaits
# Muitas punkta nosaukums
# GREBŅEVAS MKP                           1638785.00                  62
# INDRAS MKP                                14510.23                   1
# LIDOSTAS MKP                          424673348.52                1663
# Nodokļu un muitas policijas pārvald     1661150.37                 129
# Pededzes RŠV                              41500.00                   2
# PĀTERNIEKU MKP                          1156551.48                  25
# SILENES MKP                              964394.65                  15
# TEREHOVAS MKP                           4796629.69                 147
# VIENTUĻU MKP                              68826.81                   9
# ZILUPES MKP                              674798.28                  17

# %%
data_new.nlargest(10,'Kopsumma euro')
# Out:
#      Gads     Mēnesis Iebraucot vai Izbraucot     Nosūtītāja valsts  \
# 365  2019   februāris               Iebraucot  Krievijas Federācija
# 505  2019      jūlijs               Iebraucot               Gruzija
# 299  2018   novembris               Izbraucot               Latvija
# 74   2018       marts               Izbraucot               Latvija
# 153  2018      jūnijs               Izbraucot               Latvija
# 216  2018     augusts               Izbraucot               Latvija
# 269  2018    oktobris               Izbraucot               Latvija
# 326  2018   decembris               Izbraucot               Latvija
# 244  2018  septembris               Izbraucot               Latvija
# 464  2019       maijs               Izbraucot               Latvija
#
#     Galamērķa valsts  Transporta veids Muitas punkta nosaukums  Kopsumma euro  \
# 365          Latvija  Gaisa transports            LIDOSTAS MKP    31604886.40
# ...

# %%
data_new.nsmallest(10,'Kopsumma euro').sort_values('Kopsumma euro',ascending =False)
# Out:
#      Gads    Mēnesis Iebraucot vai Izbraucot     Nosūtītāja valsts  \
# 343  2019   janvāris               Iebraucot               Ukraina
# 76   2018    aprīlis               Iebraucot          Baltkrievija
# 727  2019  decembris               Izbraucot               Latvija
# 572  2019    augusts               Iebraucot               Ukraina
# 648  2019   oktobris               Iebraucot           Uzbekistāna
# 784  2020  februāris               Iebraucot  Krievijas Federācija
# 636  2019   oktobris               Iebraucot  Krievijas Federācija
# 704  2019  decembris               Iebraucot  Krievijas Federācija
# 498  2019     jūnijs               Izbraucot               Latvija
# 25   2018  februāris               Iebraucot  Krievijas Federācija
#
#          Galamērķa valsts     Transporta veids Muitas punkta nosaukums  \
# 343               Latvija  Autoceļu transports          PĀTERNIEKU MKP
# 76                Latvija  Autoceļu transports             SILENES MKP
# ...

# %%
incoming = data_new.loc[data_new['Iebraucot vai Izbraucot'] == 'Iebraucot'].rename(columns = {'Iebraucot vai Izbraucot':'Iebraucot'})
incoming
# Out:
#      Gads   Mēnesis  Iebraucot         Nosūtītāja valsts  \
# 0    2018  janvāris  Iebraucot  Apvienotie Arābu Emirāti
# 1    2018  janvāris  Iebraucot              Azerbaidžāna
# 2    2018  janvāris  Iebraucot              Baltkrievija
# 3    2018  janvāris  Iebraucot                   Izraēla
# 4    2018  janvāris  Iebraucot      Krievijas Federācija
# ..    ...       ...        ...                       ...
# 827  2020     marts  Iebraucot                   Ukraina
# 828  2020     marts  Iebraucot               Uzbekistāna
# 829  2020     marts  Iebraucot               Uzbekistāna
# 837  2020   aprīlis  Iebraucot      Krievijas Federācija
# 838  2020   aprīlis  Iebraucot                   Lietuva
#
#          Galamērķa valsts     Transporta veids  \
# 0                 Latvija     Gaisa transports
# 1                 Latvija     Gaisa transports
# 2                 Latvija  Autoceļu transports
# 3                 Latvija     Gaisa transports
# ...

# %%
inc_N = incoming[['Nosūtītāja valsts','Kopsumma euro','Deklarāciju skaits']].groupby(['Nosūtītāja valsts']).sum()
inc_N
# Out:
#                              Kopsumma euro  Deklarāciju skaits
# Nosūtītāja valsts
# Amerikas Savienotās Valstis      273770.05                   8
# Apvienotie Arābu Emirāti         475324.46                  13
# Apvienotā Karaliste              109393.31                   6
# Argentīna                          9550.00                   1
# Armēnija                          62640.11                   4
# Azerbaidžāna                     339246.03                  18
# Baltkrievija                    3559852.56                  60
# Dienvidkoreja                    155500.00                   1
# Grieķija                          27054.30                   2
# Gruzija                        33745265.30                  45
# Igaunija                          37900.00                   2
# Indija                            36260.00                   1
# Irāka                             44561.08                   1
# Islande                          154219.37                   1
# ...

# %%
len(inc_N)
# Out:
# 42

# %%
inc_G = incoming[['Galamērķa valsts','Kopsumma euro','Deklarāciju skaits']].groupby(['Galamērķa valsts']).sum()
inc_G
# Out:
#                          Kopsumma euro  Deklarāciju skaits
# Galamērķa valsts
# Apvienotā Karaliste           71120.79                   2
# Austrija                      33400.00                   2
# Baltkrievija                  13705.89                   1
# Beļģija                       21591.65                   1
# Bulgārija                     96576.12                   2
# Dānija                        12674.45                   2
# Francija                     106674.54                   4
# Grieķija                     122500.00                   3
# Gruzija                       62964.02                   2
# Igaunija                     496036.73                  18
# Itālija                      104000.00                   5
# Kipra                          7132.47                   1
# Krievijas Federācija         279746.99                   7
# Latvija                   174520577.87                1320
# Libērija                      23075.64                   1
# ...

# %%
len(inc_G)
# Out:
# 29

# %%
incoming_LR = incoming.groupby('Galamērķa valsts')
inc_LR = incoming_LR.get_group('Latvija')
inc_LR
# Out:
#      Gads   Mēnesis  Iebraucot         Nosūtītāja valsts Galamērķa valsts  \
# 0    2018  janvāris  Iebraucot  Apvienotie Arābu Emirāti          Latvija
# 1    2018  janvāris  Iebraucot              Azerbaidžāna          Latvija
# 2    2018  janvāris  Iebraucot              Baltkrievija          Latvija
# 3    2018  janvāris  Iebraucot                   Izraēla          Latvija
# 5    2018  janvāris  Iebraucot      Krievijas Federācija          Latvija
# ..    ...       ...        ...                       ...              ...
# 821  2020     marts  Iebraucot      Krievijas Federācija          Latvija
# 825  2020     marts  Iebraucot                    Šveice          Latvija
# 826  2020     marts  Iebraucot                   Ukraina          Latvija
# 828  2020     marts  Iebraucot               Uzbekistāna          Latvija
# 837  2020   aprīlis  Iebraucot      Krievijas Federācija          Latvija
#
#         Transporta veids Muitas punkta nosaukums  Kopsumma euro  \
# ...

# %%
inc_LR[['Nosūtītāja valsts','Kopsumma euro','Deklarāciju skaits']].groupby(['Nosūtītāja valsts']).sum()
# Out:
#                              Kopsumma euro  Deklarāciju skaits
# Nosūtītāja valsts
# Amerikas Savienotās Valstis      273770.05                   8
# Apvienotie Arābu Emirāti         475324.46                  13
# Apvienotā Karaliste              109393.31                   6
# Argentīna                          9550.00                   1
# Armēnija                          62640.11                   4
# Azerbaidžāna                     265846.03                  15
# Baltkrievija                    3453494.96                  54
# Dienvidkoreja                    155500.00                   1
# Grieķija                          27054.30                   2
# Gruzija                        33523304.70                  39
# Igaunija                          37900.00                   2
# Indija                            36260.00                   1
# Irāka                             44561.08                   1
# Islande                          154219.37                   1
# ...

# %%
incoming['Kopsumma euro'].sum()
# Out:
# 183684608.3

# %%
inc_LR['Kopsumma euro'].sum()
# Out:
# 174520577.87

# %%
#skaidrās naudas tranzita summa
round(183684608.3-174520577.87)
# Out:
# 9164030

# %%
incoming[['Gads','Kopsumma euro','Deklarāciju skaits']].groupby(['Gads']).sum()
# Out:
#       Kopsumma euro  Deklarāciju skaits
# Gads
# 2018    68864018.19                 683
# 2019   107576147.21                 775
# 2020     7244442.90                 164

# %%
inc_LR[['Gads','Kopsumma euro','Deklarāciju skaits']].groupby(['Gads']).sum()
# Out:
#       Kopsumma euro  Deklarāciju skaits
# Gads
# 2018    65817133.95                 575
# 2019   102994804.06                 627
# 2020     5708639.86                 118

# %%
incoming.groupby(['Gads','Mēnesis']).sum()
# Out:
#                  Kopsumma euro  Deklarāciju skaits
# Gads Mēnesis
# 2018 aprīlis        3496168.15                  49
#      augusts        3545764.15                  54
#      decembris      4602984.42                  65
#      februāris      6244771.95                  52
#      janvāris       4520428.16                  47
#      jūlijs         4802707.00                  62
#      jūnijs         7860243.90                  54
#      maijs          7811769.83                  62
#      marts          5160675.15                  54
#      novembris      3520688.48                  63
#      oktobris      12652341.83                  62
#      septembris     4645475.17                  59
# 2019 aprīlis        5013858.39                  54
#      augusts        3451128.27                  69
#      decembris      2444223.83                  69
#      februāris     32460561.87                  54
#      janvāris       4507761.71                  56
# ...

# %%
inc_LR.groupby(['Gads','Mēnesis']).sum()
# Out:
#                  Kopsumma euro  Deklarāciju skaits
# Gads Mēnesis
# 2018 aprīlis        3367693.20                  43
#      augusts        3433367.29                  47
#      decembris      4269674.01                  51
#      februāris      6040059.04                  44
#      janvāris       4477896.51                  44
#      jūlijs         4466680.69                  50
#      jūnijs         7573236.87                  47
#      maijs          7456635.25                  52
#      marts          4944235.83                  43
#      novembris      3152742.16                  53
#      oktobris      12471149.56                  56
#      septembris     4163763.54                  45
# 2019 aprīlis        4206244.87                  38
#      augusts        3135055.33                  54
#      decembris      2171770.56                  59
#      februāris     32181989.21                  47
#      janvāris       4235854.52                  46
# ...

# %%
# var redzet, ka skaidrās naudas plūsmu ietekmēja ar pandēmiju saistītie ierobežojumi.
